# %% [markdown]
# <a href="https://colab.research.google.com/github/mathyspordie1-stack/2025-assignment-numpy/blob/main/Time_series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/mathyspordie1-stack/lsst-time-series-classification.git
# Out:
# Cloning into 'lsst-time-series-classification'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.
